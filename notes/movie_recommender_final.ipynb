# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("movie.csv")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %%
movies["genres"]=movies["genres"].replace('(no genres listed)','None')

# %%
movies.drop(movies[movies['genres'] == "None"].index, inplace = True)

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# ...        ...                                                ...
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27277                     Adventure|Fantasy|Horror
#
# [27032 rows x 3 columns]

# %%
import re
def clean_title(title):
    return re.sub("[^a-zA-Z ]", "", title)
movies["clean_title"] = movies["title"].apply(clean_title)

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# ...        ...                                                ...
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27277   131262                                   Innocence (2014)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27277                     Adventure|Fantasy|Horror
#
#                                            clean_title
# 0                                           Toy Story
# 1                                             Jumanji
# 2                                    Grumpier Old Men
# 3                                   Waiting to Exhale
# 4                         Father of the Bride Part II
# ...                                                ...
# 27272  Forklift Driver Klaus The First Day on the Job
# 27273                             Kein Bund frs Leben
# 27274                            Feuer Eis  Dosenbier
# 27275                                     The Pirates
# 27277                                       Innocence
#
# [27032 rows x 4 columns]

# %%
def clean_genres(genres):
    return re.sub("[^a-zA-Z ]", " ", genres)
movies["clean_genres"] = movies["genres"].apply(clean_genres)

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# ...        ...                                                ...
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27277   131262                                   Innocence (2014)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27277                     Adventure|Fantasy|Horror
#
#                                            clean_title  \
# 0                                           Toy Story
# 1                                             Jumanji
# 2                                    Grumpier Old Men
# 3                                   Waiting to Exhale
# 4                         Father of the Bride Part II
# ...                                                ...
# 27272  Forklift Driver Klaus The First Day on the Job
# 27273                             Kein Bund frs Leben
# 27274                            Feuer Eis  Dosenbier
# 27275                                     The Pirates
# 27277                                       Innocence
#
#                                       clean_genres
# 0      Adventure Animation Children Comedy Fantasy
# 1                       Adventure Children Fantasy
# 2                                   Comedy Romance
# 3                             Comedy Drama Romance
# 4                                           Comedy
# ...                                            ...
# 27272                                Comedy Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27277                     Adventure Fantasy Horror
#
# [27032 rows x 5 columns]

# %%
movies = movies[["movieId", "clean_title", "clean_genres"]]

# %%
movies
# Out:
#        movieId                                      clean_title  \
# 0            1                                       Toy Story
# 1            2                                         Jumanji
# 2            3                                Grumpier Old Men
# 3            4                               Waiting to Exhale
# 4            5                     Father of the Bride Part II
# ...        ...                                              ...
# 27272   131252  Forklift Driver Klaus The First Day on the Job
# 27273   131254                             Kein Bund frs Leben
# 27274   131256                            Feuer Eis  Dosenbier
# 27275   131258                                     The Pirates
# 27277   131262                                       Innocence
#
#                                       clean_genres
# 0      Adventure Animation Children Comedy Fantasy
# 1                       Adventure Children Fantasy
# 2                                   Comedy Romance
# 3                             Comedy Drama Romance
# 4                                           Comedy
# ...                                            ...
# 27272                                Comedy Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27277                     Adventure Fantasy Horror
#
# [27032 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,10))
tfidf = vectorizer.fit_transform(movies["clean_genres"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def search(genre):
    genre = clean_genres(genre)         
    query_vec = vectorizer.transform([genre])           
    similarity = cosine_similarity(query_vec,tfidf).flatten()           
    indices = np.argpartition(similarity, -20)[-20:]   
    results = movies.iloc[indices][::-1]          
    return results

# %%
search("adventure")
# Out:
#        movieId                                        clean_title clean_genres
# 2452      2537                     Beyond the Poseidon Adventure     Adventure
# 7999      8682                                   Last Valley The     Adventure
# 23012   109833                             Blackbeard the Pirate     Adventure
# 23097   110134             Belle and Sebastien Belle et Sbastien     Adventure
# 13536    67098                                        Billy Budd     Adventure
# 18591    92516                            She Gods of Shark Reef     Adventure
# 25942   123499                                       The Hunters     Adventure
# 15337    78184                                    The Black Rose     Adventure
# 2392      2477                                        Firewalker     Adventure
# 14430    72276              Indian Tomb The Das indische Grabmal     Adventure
# 7093      7205                             Wind and the Lion The     Adventure
# 5868      5967                                Legend of the Lost     Adventure
# 26658   128247                             The Corsican Brothers     Adventure
# 18324    91562                                             Judex     Adventure
# 17974    90183  Captain Thunder Capitn Trueno y el Santo Grial...    Adventure
# 14476    72516                                    Plumm Summer A     Adventure
# 25765   121999                            Valley of Head Hunters     Adventure
# 1050      1070                                             Macao     Adventure
# 25766   122011                                      Voodoo Tiger     Adventure
# 5746      5845              Pursuit of DB Cooper The aka Pursuit     Adventure

# %%
import pickle
pickle.dump(movies, open("movies.pkl", "wb"))

# %%
pickle.dump(movies.to_dict(),open("movies_dict.pkl", "wb"))
