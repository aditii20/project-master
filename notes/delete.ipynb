# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("database_movies.csv")
movies_1 = pd.read_csv("database_movies.csv")

# %%
movies_1
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
import re
def clean_title(title):
    return re.sub("[^a-zA-Z ]", "", title)

# %%
movies_1["clean_title"] = movies_1["title"].apply(clean_title)

# %%
# movies['clean_genres'] = movies.clean_genres.apply(lambda x: x[0:].split(','))

# %%
movies_1.drop(['genres'], axis=1)
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                       clean_genres
# 0      Adventure Animation Children Comedy Fantasy
# 1                       Adventure Children Fantasy
# 2                                   Comedy Romance
# 3                             Comedy Drama Romance
# 4                                           Comedy
# ...

# %%
movies_1.drop(['title'], axis=1)
# Out:
#        movieId                                       genres  \
# 0            1  Adventure|Animation|Children|Comedy|Fantasy
# 1            2                   Adventure|Children|Fantasy
# 2            3                               Comedy|Romance
# 3            4                         Comedy|Drama|Romance
# 4            5                                       Comedy
# ...        ...                                          ...
# 62418   209157                                        Drama
# 62419   209159                                  Documentary
# 62420   209163                                 Comedy|Drama
# 62421   209169                           (no genres listed)
# 62422   209171                       Action|Adventure|Drama
#
#                                       clean_genres  \
# 0      Adventure Animation Children Comedy Fantasy
# 1                       Adventure Children Fantasy
# 2                                   Comedy Romance
# ...

# %%
movies_1.drop(['title',"genres"], axis=1)
# Out:
#        movieId                                 clean_genres  \
# 0            1  Adventure Animation Children Comedy Fantasy
# 1            2                   Adventure Children Fantasy
# 2            3                               Comedy Romance
# 3            4                         Comedy Drama Romance
# 4            5                                       Comedy
# ...        ...                                          ...
# 62418   209157                                        Drama
# 62419   209159                                  Documentary
# 62420   209163                                 Comedy Drama
# 62421   209169                            no genres listed
# 62422   209171                       Action Adventure Drama
#
#                               clean_title
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...

# %%
movies_1 = movies_1.astype(str)

# %%
movies_1['clean_title'] = [x.strip('()').split(',') for x in movies_1['clean_title']]

# %%
movies_1 = movies_1[["movieId", "clean_title", "clean_genres"]]

# %%
movies_1
# Out:
#       movieId                     clean_title  \
# 0           1                    [Toy Story ]
# 1           2                      [Jumanji ]
# 2           3             [Grumpier Old Men ]
# 3           4            [Waiting to Exhale ]
# 4           5  [Father of the Bride Part II ]
# ...       ...                             ...
# 62418  209157                           [We ]
# 62419  209159           [Window of the Soul ]
# 62420  209163                    [Bad Poems ]
# 62421  209169                 [A Girl Thing ]
# 62422  209171       [Women of Devils Island ]
#
#                                         clean_genres
# 0      [Adventure Animation Children Comedy Fantasy]
# 1                       [Adventure Children Fantasy]
# 2                                   [Comedy Romance]
# 3                             [Comedy Drama Romance]
# 4                                           [Comedy]
# ...                                              ...
# ...

# %%
movies_1["clean_genres"]=movies_1["clean_genres"].replace('[ no genres listed ]','[None]')
# Out:
# C:\Users\Amarpreet Kaur\AppData\Local\Temp\ipykernel_19640\3783167708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_1["clean_genres"]=movies_1["clean_genres"].replace('[ no genres listed ]','[None]')
